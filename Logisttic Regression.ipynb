# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("Insurance.csv")

# %%
df.head()
# Out:
#    Age  Work  Aware  Insurance-status
# 0   23     0      0                 0
# 1   56     1      0                 1
# 2   34     1      1                 1
# 3   57     0      0                 1
# 4   45     1      0                 1

# %%
plt.scatter(df["Age"],df["Insurance-status"],color="blue",marker="+")

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
X=df.drop("Insurance-status",axis="columns")
y=df["Insurance-status"]

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=42)

# %%
y_test
# Out:
# 0     0
# 17    1
# Name: Insurance-status, dtype: int64

# %%
model=LogisticRegression()
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
model.predict([[26,0,1]])
# Out:
# c:\Users\annad\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])

# %%
y_pred=model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
from sklearn.metrics import confusion_matrix,accuracy_score
accuracy_score(y_pred,y_test)
# Out:
# 1.0

# %%
X_test
# Out:
#     Age  Work  Aware
# 0    23     0      0
# 17   41     1      1

# %%
model.predict_proba(X_test)
# Out:
# array([[0.69089698, 0.30910302],
#        [0.17852371, 0.82147629]])

# %%
import pickle
with open("Logistic-regression.pkl","wb")as f:
    pickle.dump(model,f)

# %%
with open("Logistic-regression.pkl","rb") as f:
     s=pickle.load(f)
s.predict([[51,0,0]])
# Out:
# c:\Users\annad\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1])
