# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\annad\Documents\Machinelearning_Training\Dataset\Titanic-Dataset.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop(["PassengerId","Name","SibSp","Parch","Ticket","Cabin","Embarked"],axis="columns",inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
from sklearn.preprocessing import LabelEncoder
encode=LabelEncoder()
df["Sex"]=encode.fit_transform(df["Sex"])
df.head()
# Out:
#    Survived  Pclass  Sex   Age     Fare
# 0         0       3    1  22.0   7.2500
# 1         1       1    0  38.0  71.2833
# 2         1       3    0  26.0   7.9250
# 3         1       1    0  35.0  53.1000
# 4         0       3    1  35.0   8.0500

# %%
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64

# %%
df.fillna(df.mean(),inplace=True)

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()
X_train,X_test,y_train,y_test=train_test_split(df[["Pclass","Sex","Age","Fare"]],df["Survived"],test_size=0.2)

# %%
y_train.head()
# Out:
# 811    0
# 29     0
# 49     0
# 105    0
# 616    0
# Name: Survived, dtype: int64

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test,y_test)
# Out:
# 0.7988826815642458

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(LogisticRegression(),df[["Pclass","Sex","Age","Fare"]],df["Survived"]))
print(cross_val_score(DecisionTreeClassifier(),df[["Pclass","Sex","Age","Fare"]],df["Survived"]))
print(cross_val_score(SVC(kernel="rbf"),df[["Pclass","Sex","Age","Fare"]],df["Survived"]))
print(cross_val_score(RandomForestClassifier(n_estimators=20),df[["Pclass","Sex","Age","Fare"]],df["Survived"]))
print(cross_val_score(GaussianNB(),df[["Pclass","Sex","Age","Fare"]],df["Survived"]))
# Out:
# [0.7877095  0.78089888 0.78651685 0.7752809  0.80337079]
# [0.72067039 0.76966292 0.81460674 0.80337079 0.79213483]
# [0.5698324  0.71348315 0.69101124 0.68539326 0.69101124]
# [0.77653631 0.80337079 0.86516854 0.80337079 0.79775281]
# [0.70949721 0.79775281 0.78089888 0.75842697 0.79213483]

# %%
#i am done here

# %%
from joblib import load, dump
dump(model,"NaiveBayes.pkl")
# Out:
# ['NaiveBayes.pkl']

# %% [markdown]
# from joblib import load, dump
# dump(model,"NaiveBayes.pkl")

# %%
d=load("NaiveBayes.pkl")

# %%
d.predict_proba(X_test)
# Out:
# array([[9.63083361e-01, 3.69166387e-02],
#        [4.47118743e-01, 5.52881257e-01],
#        [1.44665650e-34, 1.00000000e+00],
#        [7.47846826e-01, 2.52153174e-01],
#        [7.51501814e-02, 9.24849819e-01],
#        [4.49305715e-01, 5.50694285e-01],
#        [2.77045136e-01, 7.22954864e-01],
#        [9.61016842e-01, 3.89831575e-02],
#        [9.63317050e-01, 3.66829502e-02],
#        [9.52642502e-01, 4.73574984e-02],
#        [9.59600149e-01, 4.03998513e-02],
#        [3.84252468e-01, 6.15747532e-01],
#        [9.55433313e-01, 4.45666874e-02],
#        [9.56747412e-01, 4.32525876e-02],
#        [9.07960549e-01, 9.20394505e-02],
#        [9.58712713e-01, 4.12872871e-02],
#        [9.27985312e-01, 7.20146881e-02],
#        [2.96646345e-01, 7.03353655e-01],
#        [9.57227905e-01, 4.27720947e-02],
#        [7.40021250e-05, 9.99925998e-01],
#        [9.34776339e-01, 6.52236607e-02],
#        [9.69943071e-01, 3.00569286e-02],
#        [7.86604830e-01, 2.13395170e-01],
# ...
